# %% [markdown]
# # Mutual Hazard Networks
#
# This notebook reproduces the figures of section 1.

# %%
import mhn
import plotting

omhn_model = mhn.model.oMHN.load("results/omhn.csv")
cmhn_model = mhn.model.oMHN.load("results/cmhn.csv")

omhn_model.plot()
cmhn_model.plot()
# Out:
# (<matplotlib.image.AxesImage at 0x7fbc01461060>,
# ...
#  <matplotlib.colorbar.Colorbar at 0x7fbc01858430>)
